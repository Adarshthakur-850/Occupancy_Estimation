# %% [markdown]
# <a href="https://colab.research.google.com/github/Adarshthakur-850/Occupancy_Estimation/blob/main/Occupancy_Estimation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = pd.read_csv("/content/Occupancy_Estimation.csv")
data.head()
# Out:
#          Date      Time  S1_Temp  S2_Temp  S3_Temp  S4_Temp  S1_Light  \
# 0  2017/12/22  10:49:41    24.94    24.75    24.56    25.38       121
# 1  2017/12/22  10:50:12    24.94    24.75    24.56    25.44       121
# 2  2017/12/22  10:50:42    25.00    24.75    24.50    25.44       121
# 3  2017/12/22  10:51:13    25.00    24.75    24.56    25.44       121
# 4  2017/12/22  10:51:44    25.00    24.75    24.56    25.44       121
#
#    S2_Light  S3_Light  S4_Light  S1_Sound  S2_Sound  S3_Sound  S4_Sound  \
# 0        34        53        40      0.08      0.19      0.06      0.06
# 1        33        53        40      0.93      0.05      0.06      0.06
# 2        34        53        40      0.43      0.11      0.08      0.06
# 3        34        53        40      0.41      0.10      0.10      0.09
# 4        34        54        40      0.18      0.06      0.06      0.06
#
#    S5_CO2  S5_CO2_Slope  S6_PIR  S7_PIR  Room_Occupancy_Count
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(data['Date'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(data, x='S1_Temp', y='Date', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-9-59304262647d>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data, x='S1_Temp', y='Date', inner='box', palette='Dark2')

# %%
from matplotlib import pyplot as plt
data['S4_Temp'].plot(kind='line', figsize=(8, 4), title='S4_Temp')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
data.plot(kind='scatter', x='S1_Temp', y='S2_Temp', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
data.plot(kind='scatter', x='S2_Temp', y='S3_Temp', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data.tail()
# Out:
#              Date      Time  S1_Temp  S2_Temp  S3_Temp  S4_Temp  S1_Light  \
# 10124  2018/01/11  08:58:07    25.06    25.13    24.69    25.31         6
# 10125  2018/01/11  08:58:37    25.06    25.06    24.69    25.25         6
# 10126  2018/01/11  08:59:08    25.13    25.06    24.69    25.25         6
# 10127  2018/01/11  08:59:39    25.13    25.06    24.69    25.25         6
# 10128  2018/01/11  09:00:09    25.13    25.06    24.69    25.25         6
#
#        S2_Light  S3_Light  S4_Light  S1_Sound  S2_Sound  S3_Sound  S4_Sound  \
# 10124         7        33        22      0.09      0.04      0.06      0.08
# 10125         7        34        22      0.07      0.05      0.05      0.08
# 10126         7        34        22      0.11      0.05      0.06      0.08
# 10127         7        34        22      0.08      0.08      0.10      0.08
# 10128         7        34        22      0.08      0.05      0.06      0.08
#
# ...

# %%
x=data.iloc[:,2:5].values
y=data.iloc[:,5].values

# %%
x
# Out:
# array([[24.94, 24.75, 24.56],
#        [24.94, 24.75, 24.56],
#        [25.  , 24.75, 24.5 ],
#        ...,
#        [25.13, 25.06, 24.69],
#        [25.13, 25.06, 24.69],
#        [25.13, 25.06, 24.69]])

# %%
y
# Out:
# array([25.38, 25.44, 25.44, ..., 25.25, 25.25, 25.25])

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,train_size = 0.80, random_state = 3)

# %%
xtrain
# Out:
# array([[25.44, 25.44, 25.38],
#        [25.44, 25.44, 24.94],
#        [25.19, 25.25, 24.63],
#        ...,
#        [25.13, 25.06, 24.56],
#        [25.31, 25.31, 24.81],
#        [25.38, 25.44, 25.44]])

# %%
ytrain
# Out:
# array([26.06, 25.81, 25.56, ..., 25.19, 25.75, 26.19])

# %%
xtest
# Out:
# array([[25.25, 25.25, 24.69],
#        [25.81, 29.  , 25.38],
#        [25.06, 25.06, 24.56],
#        ...,
#        [25.13, 25.13, 24.63],
#        [25.  , 25.  , 24.5 ],
#        [25.25, 25.25, 24.81]])

# %%
ytest
# Out:
# array([25.5 , 26.06, 25.19, ..., 25.25, 25.31, 25.63])

# %%
import numpy as np
np.unique(y,return_counts=True)
# Out:
# (array([24.94, 25.  , 25.06, 25.13, 25.19, 25.25, 25.31, 25.38, 25.44,
#         25.5 , 25.56, 25.63, 25.69, 25.75, 25.81, 25.88, 25.94, 26.  ,
#         26.06, 26.13, 26.19, 26.25, 26.31, 26.38, 26.44, 26.5 , 26.56]),
#  array([  1,  21,  34, 147, 370, 541, 525, 413, 525, 448, 474, 585, 721,
#         728, 703, 624, 444, 409, 355, 338, 211, 312, 698, 375, 116,  10,
#           1]))

# %%
np.unique(ytrain,return_counts=True)
# Out:
# (array([24.94, 25.  , 25.06, 25.13, 25.19, 25.25, 25.31, 25.38, 25.44,
#         25.5 , 25.56, 25.63, 25.69, 25.75, 25.81, 25.88, 25.94, 26.  ,
#         26.06, 26.13, 26.19, 26.25, 26.31, 26.38, 26.44, 26.5 , 26.56]),
#  array([  1,  18,  25, 114, 290, 411, 413, 331, 424, 355, 374, 470, 579,
#         573, 562, 501, 373, 340, 286, 273, 163, 257, 563, 309,  89,   8,
#           1]))

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

model = LinearRegression()

model.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.impute import SimpleImputer
import numpy as np


xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

model = KNeighborsRegressor(n_neighbors=13)

model.fit(xtrain, ytrain)

nan_indices = np.isnan(xtest).any(axis=1)
imputer = SimpleImputer(strategy='mean')
xtest_imputed = imputer.fit_transform(xtest)

ypred = model.predict(xtest_imputed)

ytest_cleaned = ytest[~nan_indices]

mae = mean_absolute_error(ytest_cleaned, ypred)
mse = mean_squared_error(ytest_cleaned, ypred)

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
# Out:
# Mean Absolute Error: 0.060459791935606445
# Mean Squared Error: 0.007620450416771323

# %%
import pandas as pd

data = pd.read_csv("/content/Occupancy_Estimation.csv")

print(data.columns)
# Out:
# Index(['Date', 'Time', 'S1_Temp', 'S2_Temp', 'S3_Temp', 'S4_Temp', 'S1_Light',
#        'S2_Light', 'S3_Light', 'S4_Light', 'S1_Sound', 'S2_Sound', 'S3_Sound',
#        'S4_Sound', 'S5_CO2', 'S5_CO2_Slope', 'S6_PIR', 'S7_PIR',
#        'Room_Occupancy_Count'],
#       dtype='object')

# %%
print(data.columns)
# Out:
# Index(['Date', 'Time', 'S1_Temp', 'S2_Temp', 'S3_Temp', 'S4_Temp', 'S1_Light',
#        'S2_Light', 'S3_Light', 'S4_Light', 'S1_Sound', 'S2_Sound', 'S3_Sound',
#        'S4_Sound', 'S5_CO2', 'S5_CO2_Slope', 'S6_PIR', 'S7_PIR',
#        'Room_Occupancy_Count'],
#       dtype='object')

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import cross_val_score, KFold
from sklearn.linear_model import LogisticRegression

data = pd.read_csv("/content/Occupancy_Estimation.csv")

X = data[['S1_Temp', 'S2_Temp']].values
y = data['Room_Occupancy_Count'].values

model = LogisticRegression()

num_folds = 5

kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)

cross_val_results = cross_val_score(model, X, y, cv=kf, scoring='accuracy')

print("Cross-validation scores:", cross_val_results)
print("Mean accuracy:", np.mean(cross_val_results))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("/content/Occupancy_Estimation.csv")

sns.pairplot(data[['S1_Temp', 'S2_Temp', 'S3_Temp', 'S4_Temp', 'S1_Light',
                   'S2_Light', 'S3_Light', 'S4_Light', 'S1_Sound', 'S2_Sound',
                   'S3_Sound', 'S4_Sound', 'S5_CO2', 'S5_CO2_Slope', 'S6_PIR',
                   'S7_PIR', 'Room_Occupancy_Count']], height=1.25)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("/content/Occupancy_Estimation.csv")

cols = ['S1_Temp', 'S2_Temp', 'S3_Temp', 'S4_Temp', 'S1_Light',
        'S2_Light', 'S3_Light', 'S4_Light', 'S1_Sound', 'S2_Sound',
        'S3_Sound', 'S4_Sound', 'S5_CO2', 'S5_CO2_Slope', 'S6_PIR',
        'S7_PIR', 'Room_Occupancy_Count']

cm = data[cols].corr()

sns.set(font_scale=0.5)
hm = sns.heatmap(cm,
                 cbar=True,
                 annot=True,
                 square=True,
                 fmt='.2f',
                 cmap='Blues',
                 annot_kws={'size': 5},
                 yticklabels=cols,
                 xticklabels=cols)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("/content/Occupancy_Estimation.csv")

cols = ['S1_Temp', 'S2_Temp', 'S3_Temp', 'S4_Temp', 'S1_Light',
        'S2_Light', 'S3_Light', 'S4_Light', 'S1_Sound', 'S2_Sound',
        'S3_Sound', 'S4_Sound', 'S5_CO2', 'S5_CO2_Slope', 'S6_PIR',
        'S7_PIR', 'Room_Occupancy_Count']

means = data[cols].mean()

plt.figure(figsize=(10, 6))
means.plot(kind='bar')
plt.title('Mean Values of Columns')
plt.xlabel('Column')
plt.ylabel('Mean Value')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("/content/Occupancy_Estimation.csv")

cols = ['S1_Temp', 'S2_Temp', 'S3_Temp', 'S4_Temp', 'S1_Light',
        'S2_Light', 'S3_Light', 'S4_Light', 'S1_Sound', 'S2_Sound',
        'S3_Sound', 'S4_Sound', 'S5_CO2', 'S5_CO2_Slope', 'S6_PIR',
        'S7_PIR', 'Room_Occupancy_Count']

means = data[cols].mean()

plt.figure(figsize=(10, 6))
means.plot(kind='bar')
plt.title('Mean Values of Columns')
plt.xlabel('Column')
plt.ylabel('Mean Value')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("/content/Occupancy_Estimation.csv")

cols = ['S1_Temp', 'S2_Temp', 'S3_Temp', 'S4_Temp', 'S1_Light',
        'S2_Light', 'S3_Light', 'S4_Light', 'S1_Sound', 'S2_Sound',
        'S3_Sound', 'S4_Sound', 'S5_CO2', 'S5_CO2_Slope', 'S6_PIR',
        'S7_PIR', 'Room_Occupancy_Count']

plt.figure(figsize=(12, 8))
for col in cols:
    sns.ecdfplot(data=data[col], stat="proportion", complementary=True, label=col)
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.title('Empirical Cumulative Distribution Function (ECDF)')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

data = pd.read_csv("/content/Occupancy_Estimation.csv")

cols = ['S1_Temp', 'S2_Temp', 'S3_Temp', 'S4_Temp', 'S1_Light',
        'S2_Light', 'S3_Light', 'S4_Light', 'S1_Sound', 'S2_Sound',
        'S3_Sound', 'S4_Sound', 'S5_CO2', 'S5_CO2_Slope', 'S6_PIR',
        'S7_PIR', 'Room_Occupancy_Count']

feature_column = 'S1_Temp'
target_column = 'Room_Occupancy_Count'
X = data[[feature_column]].values
y = data[target_column].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1)

forest = RandomForestRegressor(n_estimators=100, random_state=1, n_jobs=-1)
forest.fit(X_train, y_train)

y_train_pred = forest.predict(X_train)
y_test_pred = forest.predict(X_test)

mse_train = mean_squared_error(y_train, y_train_pred)
mse_test = mean_squared_error(y_test, y_test_pred)

print('MSE train: %.3f, test: %.3f' % (mse_train, mse_test))

r2_train = r2_score(y_train, y_train_pred)
r2_test = r2_score(y_test, y_test_pred)

print('R^2 train: %.3f, test: %.3f' % (r2_train, r2_test))

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.scatter(y_train_pred, y_train_pred - y_train, c='steelblue', edgecolor='white', marker='s', s=35, alpha=0.9, label='Training data')
plt.xlabel('Predicted values')
plt.ylabel('Residuals')
plt.title('Residuals Plot (Training)')
plt.hlines(y=0, xmin=min(y_train_pred), xmax=max(y_train_pred), lw=2, color='red')

plt.subplot(1, 2, 2)
plt.scatter(y_test_pred, y_test_pred - y_test, c='limegreen', edgecolor='white', marker='o', s=35, alpha=0.9, label='Testing data')
plt.xlabel('Predicted values')
plt.ylabel('Residuals')
plt.title('Residuals Plot (Testing)')
plt.hlines(y=0, xmin=min(y_test_pred), xmax=max(y_test_pred), lw=2, color='red')

plt.tight_layout()
plt.show()

plt.figure(figsize=(8, 6))
plt.scatter(y_train, y_train_pred, color='steelblue', edgecolor='white', marker='s', label='Training data')
plt.scatter(y_test, y_test_pred, color='limegreen', edgecolor='white', marker='o', label='Testing data')
plt.xlabel('Actual values')
plt.ylabel('Predicted values')
plt.title('Predicted vs Actual')
plt.legend(loc='upper left')
plt.show()

plt.figure(figsize=(10, 6))
plt.hist(y_train - y_train_pred, bins=30, color='steelblue', alpha=0.7, label='Training residuals')
plt.hist(y_test - y_test_pred, bins=30, color='limegreen', alpha=0.7, label='Testing residuals')
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.title('Histogram of Residuals')
plt.legend(loc='upper right')
plt.show()

plt.figure(figsize=(8, 6))
plt.scatter(X_train, y_train_pred, color='steelblue', edgecolor='white', marker='s', label='Training data')
plt.scatter(X_test, y_test_pred, color='limegreen', edgecolor='white', marker='o', label='Testing data')
plt.xlabel('Feature')
plt.ylabel('Predicted values')
plt.title('Predicted values vs Feature')
plt.legend(loc='upper left')
plt.show()
